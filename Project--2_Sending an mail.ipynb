# %%
 
#   Project--2
 
# Sending an email using python script... 
 
 
# !pip install emails

# %%
import emails
 
 
message =emails.html(html="<p>hello <br>  Message send to email while using python script...... </p>", subject="Your EMAIL FROM PYTHON SCRIPT",
 
mail_from=('Druvish', 'sai@xyz.com'))

# %%
 
mail_via_python = message.send(to='gewoyiv818@econeom.com ',
    smtp={'host': 'smtp.gmail.com','timeout': 5,'port':587,
    'user':'hdivya019@gmail.com',
    'password':'yashas@d45',
    'tls':True})
print("sent successfully ")
# Out:
# sent successfully
